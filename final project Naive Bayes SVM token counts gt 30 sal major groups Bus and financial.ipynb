# %%
# Start final project import modules
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
# %matplotlib inline
import sys
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder 
from sklearn import feature_extraction
from __future__ import print_function
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %%
# read in the datasets
 
#jd = pd.read_csv('job_data_dict_30_sample.csv')
#jd = pd.read_csv('job_data_dict_sal_weighted_30_sample.csv')
#jd = pd.read_csv('job_data_dict_all_sal_weighted.csv')
jd = pd.read_csv('job_data_dict_all_sal_weighted_major.csv')

# %%
#1. Explore the dataset: 
    # There is a mix of string and numeric data. There are some variables that can be converted to dummy or binary values.
    # While there are no NAs there are unknown values in some of the string data which may need to be treated as NAs.

#jd.describe(include='all')
jd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9716 entries, 0 to 9715
# Data columns (total 12 columns):
# Unnamed: 0          9716 non-null int64
# major_des           9716 non-null object
# jobs                9716 non-null object
# jobtitle            9716 non-null object
# onetcode            9716 non-null object
# major_code          9716 non-null int64
# dictionary          9716 non-null object
# p_an                9716 non-null float64
# p_an_normal         9716 non-null float64
# lowct               9716 non-null int64
# major_dictionary    9716 non-null object
# uid                 9716 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 986.8+ KB

# %%
jd.head()
# Out:
#    Unnamed: 0   major_des                                       jobs  \
# 0           2  Management  computer and information systems managers
# 1           6  Management    financial managers branch or department
# 2          16  Management                   human resources managers
# 3          28  Management                 treasurers and controllers
# 4          31  Management    financial managers branch or department
#
#                                          jobtitle    onetcode  major_code  \
# 0  director of it planning development deployment  11-3021.00          11
# 1                   accounting manager supervisor  11-3031.02          11
# 2                         human resources manager  11-3040.00          11
# 3                            corporate controller  11-3031.01          11
# 4                   accounting manager supervisor  11-3031.02          11
#
#                                           dictionary      p_an  p_an_normal  \
# 0  director planning development deployment direc...  110000.0     0.097679
# 1  accounting manager supervisor accounting manag...   45000.0     0.031779
# 2  human resources manager human resources manage...   91197.5     0.078616
# 3  corporate controller corporate controller year...  115000.0     0.102748
# 4  accounting manager supervisor accounting manag...   82500.0     0.069798
#
#    lowct                                   major_dictionary  uid
# 0      0  computer information systems managers computer...    1
# 1      0  financial managers branch department financial...    2
# 2      0  human resources managers human resources manag...    3
# 3      0  treasurers controllers treasurers controllers ...    4
# 4      0  financial managers branch department financial...    5

# %%
cat_columns = ['major_des', 'jobs','jobtitle','dictionary','major_dictionary', 'p_an_normal', 'lowct']
major_feat_col = ['major_dictionary', 'p_an_normal']   
feat_col = ['dictionary', 'p_an_normal']
string_variables = ['jobs']

jd_2 = jd[cat_columns]
jd_2.head()
# Out:
#     major_des                                       jobs  \
# 0  Management  computer and information systems managers
# 1  Management    financial managers branch or department
# 2  Management                   human resources managers
# 3  Management                 treasurers and controllers
# 4  Management    financial managers branch or department
#
#                                          jobtitle  \
# 0  director of it planning development deployment
# 1                   accounting manager supervisor
# 2                         human resources manager
# 3                            corporate controller
# 4                   accounting manager supervisor
#
#                                           dictionary  \
# 0  director planning development deployment direc...
# 1  accounting manager supervisor accounting manag...
# 2  human resources manager human resources manage...
# 3  corporate controller corporate controller year...
# 4  accounting manager supervisor accounting manag...
#
#                                     major_dictionary  p_an_normal  lowct
# 0  computer information systems managers computer...     0.097679      0
# 1  financial managers branch department financial...     0.031779      0
# 2  human resources managers human resources manag...     0.078616      0
# 3  treasurers controllers treasurers controllers ...     0.102748      0
# 4  financial managers branch department financial...     0.069798      0

# %%
# subset the data to the major groups
jd_3 = jd_2[jd_2.major_des=='Business and Financial Operations']
jd_3 = jd_3[jd_3.lowct==0]

# %%
jd_3.jobs.value_counts().min()
# Out:
# 28

# %%
#df_numerical = jd_2.copy()
#encoder_dict = {}

#for col in string_variables:
#    le = preprocessing.LabelEncoder()
#    le.fit(jd_2[col])
#    encoder_dict[col] = le
#    df_numerical[col] = le.transform(jd_2[col])

#df_numerical.head()

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(jd_3[feat_col], jd_3['jobs'], random_state=1)

# %%
#feat = list(df_numerical.dictionary.values.flatten())
#type(feat)
#feat = unicode(feat, 'utf-8')

# %%
#df_numerical.dictionary[0]
#import sys  

#reload(sys)  
#sys.setdefaultencoding('utf8')
#y_test

# %%
X_test.shape
# Out:
# (230L, 2L)

# %%
X_train.shape
# Out:
# (687L, 2L)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(decode_error = 'ignore')
#vect = CountVectorizer()
#vect.fit(X_train)
#vect.transform(X_train)

# %%
#vect.get_feature_names()
# learn vocabulary and create document-term matrix in a single step
train_dtm = vect.fit_transform(X_train[:,0])
train_dtm
# Out:
# <687x1323 sparse matrix of type '<type 'numpy.int64'>'
# 	with 6483 stored elements in Compressed Sparse Row format>

# %%
# transform testing data into a document-term matrix
test_dtm = vect.transform(X_test[:,0])
type(test_dtm)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
train_features = vect.get_feature_names()
len(train_features)
# Out:
# 1323

# %%
train_features = train_features + list('s')

# %%
len(train_features)
# Out:
# 1324

# %%
train_sal = np.array(X_train[:,1])
train_sal = train_sal[...,None]
type(train_sal)
# Out:
# numpy.ndarray

# %%
test_sal = np.array(X_test[:,1])
test_sal = test_sal[...,None]
type(test_sal)
# Out:
# numpy.ndarray

# %%
train_dtm_2 = np.array(train_dtm.todense())
type(train_dtm_2)
# Out:
# numpy.ndarray

# %%
test_dtm_2 = np.array(test_dtm.todense())

# %%
test_dtm_2.shape
# Out:
# (230L, 1323L)

# %%
train_dtm_2.shape
# Out:
# (687L, 1323L)

# %%
train_dtm2 = np.append(train_dtm_2, train_sal,1)

# %%
type(train_dtm2)
train_dtm2.shape
# Out:
# (687L, 1324L)

# %%
test_dtm2 = np.append(test_dtm_2, test_sal, 1)

# %%
# convert train_dtm to a regular array
#train_arr = train_dtm2.toarray()
#train_arr

# %%
# exercise: create a DataFrame of tokens with their counts.
train_token_counts = pd.DataFrame({'token':train_features, 'count':np.sum(train_dtm2, axis=0)})
train_token_counts.sort_index(by='count', ascending=False)
# Out:
#      count           token
# 1110   499          senior
# 68     451         analyst
# 9      397      accountant
# 497    296       financial
# 1160   253           staff
# 738    197         manager
# 12     188      accounting
# 293    187      controller
# 1008   179       recruiter
# 113    156         auditor
# 103    119       assistant
# 252    118    compensation
# 1151   110      specialist
# 218    108  classification
# 167    105        business
# 249    103         company
# 827     99      operations
# 902     91        position
# 465     86      experience
# 288     85        contract
# 332     79            data
# 496     79         finance
# 302     79     coordinator
# 221     75          client
# 717     67            loan
# 305     65       corporate
# 1158    62              sr
# 281     61      consultant
# 1322    60           years
# 1103    57         seeking
# ...    ...             ...
# 408      1         efforts
# 407      1    efficiencies
# 406      1   effectiveness
# 1297     1          vision
# 1298     1         volcker
# 6        1   accommodation
# 1300     1    vpaccounting
# 5        1      accidental
# 405      1       effective
# 388      1   documentation
# 1304     1      webfilings
# 1305     1         website
# 402      1        economic
# 1307     1          weekly
# 401      1         earning
# 1309     1        whitford
# 1310     1       wholesale
# 239      1          coming
# 1312     1        willwork
# 1313     1           wires
# 1314     1           words
# 241      1      commerical
# 2        1      acceptance
# 389      1       documents
# 1318     1          worlds
# 1319     1       worldwide
# 1320     1         writing
# 395      1         drivers
# 392      1        drafting
# 661      1        investor
#
# [1324 rows x 2 columns]

# %%
# train a Naive Bayes model using train_dtm
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(train_dtm2, y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:427: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   self.feature_count_ += safe_sparse_dot(Y.T, X)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# make predictions on test data using test_dtm
preds = nb.predict(test_dtm2)
preds
# Out:
# array(['management analysts', 'business operations specialists',
#        'accountants', 'accountants', 'management analysts',
#        'business operations specialists',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'auditors', 'accountants', 'personnel recruiters',
#        'financial analysts', 'accountants', 'accountants', 'accountants',
#        'personnel recruiters', 'personnel recruiters',
#        'personnel recruiters', 'financial analysts', 'accountants',
#        'logisticians', 'accountants', 'financial analysts',
#        'financial analysts', 'financial analysts', 'personnel recruiters',
#        'accountants', 'logisticians', 'auditors', 'management analysts',
#        'accountants', 'accountants', 'accountants', 'personnel recruiters',
#        'business operations specialists', 'loan officers',
#        'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants', 'auditors', 'management analysts',
#        'business operations specialists', 'accountants',
#        'business operations specialists', 'accountants', 'accountants',
#        'management analysts', 'financial analysts', 'loan officers',
#        'auditors', 'accountants', 'accountants', 'personnel recruiters',
#        'accountants', 'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'financial analysts', 'loan officers',
#        'accountants', 'personnel recruiters', 'accountants',
#        'personnel recruiters', 'financial analysts', 'accountants',
#        'auditors', 'accountants', 'accountants', 'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'management analysts', 'financial analysts',
#        'accountants', 'auditors', 'logisticians', 'accountants',
#        'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'auditors', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'management analysts', 'auditors',
#        'financial analysts', 'auditors', 'accountants',
#        'financial analysts', 'financial analysts', 'accountants',
#        'accountants', 'personnel recruiters', 'accountants', 'accountants',
#        'accountants', 'accountants', 'accountants', 'auditors',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'accountants', 'accountants',
#        'financial analysts', 'accountants', 'accountants', 'accountants',
#        'financial analysts', 'financial analysts', 'auditors',
#        'accountants', 'financial analysts', 'management analysts',
#        'accountants', 'business operations specialists',
#        'management analysts', 'accountants', 'management analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants', 'auditors', 'management analysts', 'accountants',
#        'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'management analysts', 'logisticians', 'auditors', 'accountants',
#        'accountants', 'accountants', 'loan officers', 'accountants',
#        'personnel recruiters', 'accountants', 'management analysts',
#        'accountants', 'personnel recruiters', 'auditors', 'accountants',
#        'management analysts', 'accountants', 'logisticians',
#        'financial analysts', 'management analysts', 'loan officers',
#        'accountants', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'management analysts',
#        'financial analysts', 'personnel recruiters', 'financial analysts',
#        'financial analysts', 'accountants', 'accountants', 'auditors',
#        'personnel recruiters', 'auditors', 'personnel recruiters',
#        'management analysts', 'management analysts', 'accountants',
#        'accountants', 'business operations specialists', 'logisticians',
#        'accountants', 'personnel recruiters', 'financial analysts',
#        'auditors', 'personnel recruiters', 'accountants',
#        'financial analysts', 'accountants', 'financial analysts',
#        'accountants', 'accountants', 'business operations specialists',
#        'auditors', 'accountants', 'financial analysts',
#        'management analysts', 'financial analysts', 'management analysts',
#        'management analysts', 'management analysts',
#        'personnel recruiters', 'personnel recruiters', 'auditors',
#        'accountants', 'accountants', 'accountants', 'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants', 'personnel recruiters', 'accountants',
#        'personnel recruiters', 'management analysts',
#        'management analysts', 'management analysts', 'management analysts',
#        'auditors', 'auditors',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'management analysts', 'accountants',
#        'logisticians', 'management analysts', 'loan officers',
#        'accountants', 'management analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'personnel recruiters', 'financial analysts', 'accountants',
#        'accountants'],
#       dtype='|S59')

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, preds))
print(metrics.confusion_matrix(y_test, preds))
# Out:
# 0.860869565217
# [[83  0  0  5  0  0  2  0  0]
#  [ 0 21  0  0  0  0  0  0  0]
#  [ 2  0  6  1  0  1  3  0  0]
#  [ 2  0  0 20  0  0  1  0  0]
#  [ 1  0  0  1  6  0  0  0  0]
#  [ 0  0  0  0  0  6  0  0  1]
#  [ 2  0  1  6  0  0 23  0  0]
#  [ 1  0  0  0  0  0  0 21  0]
#  [ 0  0  1  0  0  0  0  1 12]]

# %%
# predict (poorly calibrated) probabilities and calculate AUC
#probs = nb.predict_proba(test_dtm2)[:, 1]
#probs
#print(metrics.roc_auc_score(y_test, probs))

# %%
# exercise: show the message text for the false positives
#X_test[y_test < preds]

# %%
# exercise: show the message text for the false negatives
#X_test[y_test > preds]

# %%
from sklearn.metrics import classification_report 

print(classification_report(y_test, preds) )
# Out:
#              precision    recall  f1-score   support
#
# accountants       0.91      0.92      0.92        90
#    auditors       1.00      1.00      1.00        21
# business operations specialists       0.75      0.46      0.57        13
# financial analysts       0.61      0.87      0.71        23
# loan officers       1.00      0.75      0.86         8
# logisticians       0.86      0.86      0.86         7
# management analysts       0.79      0.72      0.75        32
# personnel recruiters       0.95      0.95      0.95        22
# purchasing agents except wholesale retail and farm products       0.92      0.86      0.89        14
#
# avg / total       0.87      0.86      0.86       230

# %%
# use SVM
from sklearn import svm
svc = svm.SVC(kernel='linear', probability = True)

svc.fit(train_dtm2, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='linear', max_iter=-1, probability=True, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# make predictions on test data using test_dtm
preds = svc.predict(test_dtm2)
preds
# Out:
# array(['financial analysts', 'business operations specialists',
#        'accountants', 'accountants', 'management analysts',
#        'business operations specialists',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'auditors', 'accountants', 'personnel recruiters', 'accountants',
#        'accountants', 'accountants', 'accountants', 'personnel recruiters',
#        'personnel recruiters', 'personnel recruiters',
#        'financial analysts', 'accountants', 'logisticians', 'accountants',
#        'financial analysts', 'financial analysts', 'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants', 'logisticians', 'auditors', 'management analysts',
#        'accountants', 'accountants', 'accountants', 'personnel recruiters',
#        'business operations specialists', 'loan officers',
#        'financial analysts', 'accountants', 'accountants', 'auditors',
#        'business operations specialists', 'management analysts',
#        'accountants', 'business operations specialists', 'accountants',
#        'accountants', 'management analysts', 'financial analysts',
#        'loan officers', 'auditors', 'accountants', 'accountants',
#        'personnel recruiters', 'accountants', 'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'financial analysts', 'loan officers',
#        'accountants', 'personnel recruiters', 'accountants',
#        'personnel recruiters', 'financial analysts', 'accountants',
#        'auditors', 'accountants', 'accountants', 'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'management analysts', 'financial analysts',
#        'accountants', 'auditors', 'logisticians', 'accountants',
#        'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'auditors', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'management analysts', 'auditors',
#        'financial analysts', 'auditors', 'accountants',
#        'financial analysts', 'accountants', 'accountants', 'accountants',
#        'personnel recruiters', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'auditors',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'accountants', 'accountants', 'accountants',
#        'accountants', 'accountants', 'accountants', 'accountants',
#        'financial analysts', 'financial analysts', 'accountants',
#        'accountants', 'financial analysts', 'financial analysts',
#        'auditors', 'accountants', 'financial analysts',
#        'management analysts', 'accountants',
#        'business operations specialists', 'management analysts',
#        'accountants', 'management analysts', 'logisticians',
#        'purchasing agents except wholesale retail and farm products',
#        'business operations specialists', 'auditors',
#        'management analysts', 'accountants', 'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'management analysts', 'logisticians', 'auditors', 'accountants',
#        'accountants', 'accountants', 'loan officers', 'accountants',
#        'accountants', 'accountants', 'financial analysts', 'accountants',
#        'personnel recruiters', 'auditors', 'accountants',
#        'management analysts', 'accountants', 'logisticians',
#        'financial analysts', 'management analysts', 'loan officers',
#        'accountants', 'accountants', 'accountants', 'loan officers',
#        'accountants', 'accountants', 'business operations specialists',
#        'financial analysts', 'personnel recruiters', 'accountants',
#        'financial analysts', 'accountants', 'accountants', 'auditors',
#        'personnel recruiters', 'auditors', 'personnel recruiters',
#        'management analysts', 'management analysts', 'accountants',
#        'accountants', 'business operations specialists', 'logisticians',
#        'accountants', 'personnel recruiters', 'financial analysts',
#        'auditors', 'personnel recruiters', 'accountants',
#        'financial analysts', 'accountants', 'financial analysts',
#        'accountants', 'personnel recruiters',
#        'business operations specialists', 'auditors', 'accountants',
#        'accountants', 'management analysts', 'financial analysts',
#        'accountants', 'management analysts', 'management analysts',
#        'personnel recruiters', 'personnel recruiters', 'accountants',
#        'accountants', 'accountants', 'accountants', 'accountants',
#        'purchasing agents except wholesale retail and farm products',
#        'accountants', 'personnel recruiters', 'accountants',
#        'personnel recruiters', 'management analysts',
#        'management analysts', 'management analysts', 'management analysts',
#        'auditors', 'auditors',
#        'purchasing agents except wholesale retail and farm products',
#        'financial analysts', 'accountants', 'accountants', 'logisticians',
#        'management analysts', 'loan officers', 'accountants',
#        'financial analysts',
#        'purchasing agents except wholesale retail and farm products',
#        'personnel recruiters', 'financial analysts', 'accountants',
#        'accountants'], dtype=object)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, preds))
print(metrics.confusion_matrix(y_test, preds))
# Out:
# 0.865217391304
# [[86  0  0  4  0  0  0  0  0]
#  [ 1 20  0  0  0  0  0  0  0]
#  [ 1  0  7  1  0  1  3  0  0]
#  [ 2  0  0 20  1  0  0  0  0]
#  [ 1  0  0  1  6  0  0  0  0]
#  [ 0  0  0  0  0  7  0  0  0]
#  [ 4  0  2  6  0  0 20  0  0]
#  [ 1  0  0  0  0  0  0 21  0]
#  [ 1  0  1  0  0  0  0  0 12]]

# %%
# try using all of the data

# %%
train_dtm = vect.fit_transform(jd_3['dictionary'])
train_dtm_2 = np.array(train_dtm.todense())
type(train_dtm_2)
# Out:
# numpy.ndarray

# %%
train_sal = np.array(jd_3['p_an_normal'])
train_sal = train_sal[...,None]
type(train_sal)
# Out:
# numpy.ndarray

# %%
train_dtm2 = np.append(train_dtm_2, train_sal,1)

# %%
# train a Naive Bayes model using train_dtm
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(train_dtm2, jd_3['jobs'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
preds = nb.predict(train_dtm2)
preds.shape
# Out:
# (917L,)

# %%
print(classification_report(jd_3['jobs'], preds) )
# Out:
#              precision    recall  f1-score   support
#
# accountants       0.99      0.94      0.97       387
#    auditors       1.00      0.99      0.99        81
# business operations specialists       0.98      0.89      0.93        54
# financial analysts       0.81      0.96      0.88       109
# loan officers       1.00      0.98      0.99        41
# logisticians       0.96      0.96      0.96        28
# management analysts       0.89      0.95      0.92        82
# personnel recruiters       0.98      1.00      0.99        92
# purchasing agents except wholesale retail and farm products       0.98      0.98      0.98        43
#
# avg / total       0.96      0.96      0.96       917

# %%
target_predicted = nb.predict(train_dtm2)
target_prob = nb.predict_proba(train_dtm2)

#print(target_test)
#print(target_predicted)
#print(target_prob.mean())

pd.crosstab(jd_3['jobs'], target_predicted, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted                                                    accountants  \
# True
# accountants                                                          364
# auditors                                                               1
# business operations specialists                                        0
# financial analysts                                                     0
# loan officers                                                          0
# logisticians                                                           0
# management analysts                                                    1
# personnel recruiters                                                   0
# purchasing agents except wholesale retail and farm products            0
# All                                                                  366
#
# Predicted                                                    auditors  \
# True
# accountants                                                         0
# auditors                                                           80
# business operations specialists                                     0
# financial analysts                                                  0
# loan officers                                                       0
# logisticians                                                        0
# management analysts                                                 0
# personnel recruiters                                                0
# purchasing agents except wholesale retail and farm products         0
# All                                                                80
#
# Predicted                                                    business operations specialists  \
# True
# accountants                                                                                1
# auditors                                                                                   0
# business operations specialists                                                           48
# financial analysts                                                                         0
# loan officers                                                                              0
# logisticians                                                                               0
# management analysts                                                                        0
# personnel recruiters                                                                       0
# purchasing agents except wholesale retail and farm products                                0
# All                                                                                       49
#
# Predicted                                                    financial analysts  \
# True
# accountants                                                                  20
# auditors                                                                      0
# business operations specialists                                               0
# financial analysts                                                          105
# loan officers                                                                 1
# logisticians                                                                  0
# management analysts                                                           3
# personnel recruiters                                                          0
# purchasing agents except wholesale retail and farm products                   0
# All                                                                         129
#
# Predicted                                                    loan officers  \
# True
# accountants                                                              0
# auditors                                                                 0
# business operations specialists                                          0
# financial analysts                                                       0
# loan officers                                                           40
# logisticians                                                             0
# management analysts                                                      0
# personnel recruiters                                                     0
# purchasing agents except wholesale retail and farm products              0
# All                                                                     40
#
# Predicted                                                    logisticians  \
# True
# accountants                                                             0
# auditors                                                                0
# business operations specialists                                         1
# financial analysts                                                      0
# loan officers                                                           0
# logisticians                                                           27
# management analysts                                                     0
# personnel recruiters                                                    0
# purchasing agents except wholesale retail and farm products             0
# All                                                                    28
#
# Predicted                                                    management analysts  \
# True
# accountants                                                                    2
# auditors                                                                       0
# business operations specialists                                                4
# financial analysts                                                             4
# loan officers                                                                  0
# logisticians                                                                   0
# management analysts                                                           78
# personnel recruiters                                                           0
# purchasing agents except wholesale retail and farm products                    0
# All                                                                           88
#
# Predicted                                                    personnel recruiters  \
# True
# accountants                                                                     0
# auditors                                                                        0
# business operations specialists                                                 1
# financial analysts                                                              0
# loan officers                                                                   0
# logisticians                                                                    0
# management analysts                                                             0
# personnel recruiters                                                           92
# purchasing agents except wholesale retail and farm products                     1
# All                                                                            94
#
# Predicted                                                    purchasing agents except wholesale retail and farm products  \
# True
# accountants                                                                                                  0
# auditors                                                                                                     0
# business operations specialists                                                                              0
# financial analysts                                                                                           0
# loan officers                                                                                                0
# logisticians                                                                                                 1
# management analysts                                                                                          0
# personnel recruiters                                                                                         0
# purchasing agents except wholesale retail and farm products                                                 42
# All                                                                                                         43
#
# Predicted                                                    All
# True
# accountants                                                  387
# auditors                                                      81
# business operations specialists                               54
# financial analysts                                           109
# loan officers                                                 41
# logisticians                                                  28
# management analysts                                           82
# personnel recruiters                                          92
# purchasing agents except wholesale retail and farm products   43
# All                                                          917

# %%
from sklearn.cross_validation import cross_val_score
cross_val_score(nb, train_dtm, jd_3['jobs'], cv=5, scoring='accuracy').mean()
# Out:
# 0.85927054090864208
