# %%
# Start final project import modules
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
# %matplotlib inline
import sys
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder 
from sklearn import feature_extraction
from __future__ import print_function
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %%
# read in the datasets
 
jd = pd.read_csv('jobs_data.csv')
# Out:
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:1159: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
#1. Explore the dataset: 
    # There is a mix of string and numeric data. There are some variables that can be converted to dummy or binary values.
    # While there are no NAs there are unknown values in some of the string data which may need to be treated as NAs.

#jd.describe(include='all')
#jd.info()

# %%
#Input variables:
# Job.Title.og  - customer entered job title
# jobs - cleaned customer entered job title, formatted to remove punctuation, make lower case, fix spelling errors, abbreviations etc.
# Industry - clustered NAICS codes
# CBSA.Title - Census Bureau Statistical Area matched by city, state
# STATE - client state
# an.sal - employee annual salary
# bonus - employee bonus
# Age - employee age
# BLS.Verticals - industries designated by BLS NAICS codes
# CITY - client city
# POSTAL - client zip code
# city.state - client city and state
# EG.abbr.1 - employee ethnicity
# Full.Time.Part.Time - employee full time or part time
# Gender - Male, Female, unknown
# Marital.Status - Married, Single, unknown
# NAICS.2 - 2 digit NAICS code
# NAICS.2.des - 2 digit NAICS code description
# NAICS.3 - 3 digit NAICS code
# NAICS.3.des - 3 digit NAICS code description
# NAICS.4 - 4 digit NAICS code
# NAICS.4.des - 4 digit NAICS code description
# NAICS.5 - 5 digit NAICS code
# NAICS.5.des - 5 digit NAICS code description
# Regular.Temporary - employee regular or temporary
# Salaried.Hourly - employee salaried or hourly
# Workers.Comp.Code - workers comp code
# Job.Code - EEOC reporting code
# Job.Code.Description - EEOC reporting code description
# supervisor - is empoloyee a supervisor 0/1
# Collapsing.Job.Title - target job titles
# groups - Functional job groupings: Admin, Executive, Marketing, Operations, Sales, Software Engineering
# uid - unique observation identifier

# %%
#cat_columns = ['jobs', 'Industry', 'city.state', 'an.sal', 'bonus', 'Age', 'EG.abbr.1', 'Full.Time.Part.Time', 'Gender', 'Marital.Status',
#               'Regular.Temporary', 'Salaried.Hourly', 'Workers.Comp.Code', 'Job.Code', 'supervisor', 'groups', 'Collapsing.Job.Title']
#len(cat_columns)

# %%
# There are many variables that can be excluded due to similarity with other columns, but should be used to test predictive power

catagorical_var = ['Job.Title.og', 'Industry', 'city.state', 'EG.abbr.1', 'Gender', 'Marital.Status','Workers.Comp.Code',
                   'Job.Code', 'groups', 'Collapsing.Job.Title']

binary_var = ['Full.Time.Part.Time', 'Regular.Temporary', 'Salaried.Hourly']

numeric_var = ['an.sal', 'bonus', 'Age', 'supervisor']
    
string_variables = catagorical_var + binary_var

cat_columns = string_variables + numeric_var

jd_2 = jd[cat_columns]
jd_2.head()
# Out:
#                     Job.Title.og            Industry     city.state EG.abbr.1  \
# 0                      principal  financial services  menlo park ca         w
# 1               managing partner  financial services  menlo park ca         w
# 2  director of latin america and   personal services    bellevue wa         h
# 3              medical assistant   personal services     anaheim ca         h
# 4           medical front office   personal services     anaheim ca         h
#
#    Gender Marital.Status Workers.Comp.Code Job.Code      groups  \
# 0    male        married              8810   30004F  Operations
# 1    male         single              8810   30004F  Operations
# 2    male        married              5301   300N8W  Operations
# 3  female         single              8834   300106  Operations
# 4  female        married              8834   30009H  Operations
#
#   Collapsing.Job.Title Full.Time.Part.Time Regular.Temporary Salaried.Hourly  \
# 0            principal           full time           Regular        Salaried
# 1     managing partner           full time           Regular        Salaried
# 2             director           full time           Regular        Salaried
# 3            assistant           full time           Regular          Hourly
# 4               office           full time           Regular          Hourly
#
#           an.sal  bonus  Age  supervisor
# 0   12480.000000      0   56           0
# 1   62496.000000      0   58           1
# 2  133844.571429      0   51           0
# 3   35835.000000    500   30           0
# 4   34516.000000    500   29           0

# %%
df_numerical_2 = jd_2.copy()
encoder_dict = {}

for col in string_variables:
    le = preprocessing.LabelEncoder()
    le.fit(jd_2[col])
    encoder_dict[col] = le
    df_numerical_2[col] = le.transform(jd_2[col])

#df_numerical_2.head()

# %%
feature_cols = list(df_numerical_2.columns.values)

feature_cols.remove('Collapsing.Job.Title')
len(feature_cols)
# Out:
# 16

# %%
# define X and y
X = df_numerical_2[feature_cols].values
y =df_numerical_2['Collapsing.Job.Title'].values

# split into train/test
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# use 
treeclf = RandomForestClassifier(random_state=1)
treeclf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0)

# %%
pd.DataFrame({'feature':feature_cols, 'importance':treeclf.feature_importances_}).sort('importance', ascending = False)
# Out:
#                 feature  importance
# 0          Job.Title.og    0.307386
# 7              Job.Code    0.111963
# 12               an.sal    0.108644
# 2            city.state    0.099090
# 14                  Age    0.084007
# 6     Workers.Comp.Code    0.070502
# 13                bonus    0.063240
# 1              Industry    0.038996
# 8                groups    0.038260
# 3             EG.abbr.1    0.028167
# 5        Marital.Status    0.018810
# 4                Gender    0.011277
# 15           supervisor    0.008023
# 11      Salaried.Hourly    0.005015
# 9   Full.Time.Part.Time    0.004353
# 10    Regular.Temporary    0.002267

# %%
scores = cross_val_score(treeclf, X_train, y_train, cv = 5, scoring = 'accuracy')
cvs_2 = np.mean(scores)
cvs_2
# Out:
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:413: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=5.
#   % (min_labels, self.n_folds)), Warning)
# 0.55765397071296441

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

#pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)

# %%
y_pred
# Out:
# array([2149,  200,  902, ..., 1751, 1751,    9], dtype=int64)

# %%
(encoder_dict['Collapsing.Job.Title'].classes_)
# Out:
# array(['account', 'account administrator', 'account analyst', ...,
#        'x technician', 'xena technician', 'yeti outfitter'], dtype=object)

# %%
key = pd.DataFrame({'Collapsing.Job.Title':jd_2['Collapsing.Job.Title'],'Collapsing.Job.Title.code':df_numerical_2['Collapsing.Job.Title']})
key.head()
#len(key)
# Out:
#   Collapsing.Job.Title  Collapsing.Job.Title.code
# 0            principal                       1413
# 1     managing partner                       1187
# 2             director                        634
# 3            assistant                        136
# 4               office                       1286

# %%
key_2 = pd.DataFrame({'Collapsing.Job.Title.pred':jd_2['Collapsing.Job.Title'],'Collapsing.Job.Title.pred.code':df_numerical_2['Collapsing.Job.Title']})
key_2.head()
# Out:
#   Collapsing.Job.Title.pred  Collapsing.Job.Title.pred.code
# 0                 principal                            1413
# 1          managing partner                            1187
# 2                  director                             634
# 3                 assistant                             136
# 4                    office                            1286

# %%
key_u= key.drop_duplicates()
key_2u = key_2.drop_duplicates()
len(key_u)
len(key_2u)
#key_u.head()
# Out:
# 2394

# %%
pred = pd.DataFrame({'Collapsing.Job.Title.pred.code':y_pred, 'Collapsing.Job.Title.code':y_test})
len(pred)
pred.head()
# Out:
#    Collapsing.Job.Title.code  Collapsing.Job.Title.pred.code
# 0                       2148                            2149
# 1                        459                             200
# 2                        902                             902
# 3                        791                             791
# 4                       1263                            1263

# %%
pred_ck = pd.merge(pred, key_2u, how='inner', on=['Collapsing.Job.Title.pred.code'])
pred_ck.head()
# Out:
#    Collapsing.Job.Title.code  Collapsing.Job.Title.pred.code  \
# 0                       2148                            2149
# 1                       2148                            2149
# 2                       2149                            2149
# 3                        459                             200
# 4                        200                             200
#
#       Collapsing.Job.Title.pred
# 0  technical operations manager
# 1  technical operations manager
# 2  technical operations manager
# 3       audio visual technician
# 4       audio visual technician

# %%
#pred_ck = pd.merge(pred, key_u, how='inner', on=['Job.Title.og.code'])
pred_ck2 = pd.merge(pred_ck, key_u, how='inner', on=['Collapsing.Job.Title.code'])
pred_ck2.head()
#len(pred_ck)
# Out:
#    Collapsing.Job.Title.code  Collapsing.Job.Title.pred.code  \
# 0                       2148                            2149
# 1                       2148                            2149
# 2                       2148                            2148
# 3                       2148                            2148
# 4                       2149                            2149
#
#       Collapsing.Job.Title.pred          Collapsing.Job.Title
# 0  technical operations manager  technical operations analyst
# 1  technical operations manager  technical operations analyst
# 2  technical operations analyst  technical operations analyst
# 3  technical operations analyst  technical operations analyst
# 4  technical operations manager  technical operations manager

# %%
pred_ck2['match'] = 0

pred_ck2['match'][pred_ck2['Collapsing.Job.Title.code']==pred_ck2['Collapsing.Job.Title.pred.code']] =1
# Out:
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pred_ck2.match.value_counts()
# Out:
# 1    21751
# 0     2597
# dtype: int64

# %%
pred_ck2[pred_ck2.match==0]
# Out:
#        Collapsing.Job.Title.code  Collapsing.Job.Title.pred.code  \
# 0                           2148                            2149
# 1                           2148                            2149
# 5                           2149                            2148
# 6                            459                             200
# 7                            459                            1436
# 8                            459                            1190
# 9                            459                            1190
# 10                           459                             905
# 11                           459                            1150
# 12                           459                            1150
# 13                           459                            1150
# 14                           459                             586
# 15                           459                             586
# 16                           459                              21
# 17                           459                            1020
# 18                           459                            1020
# 19                           459                            1318
# 20                           459                             812
# 21                           459                             776
# 22                           459                            1070
# 23                           459                             483
# 74                           459                             675
# 75                           459                             461
# 76                           459                              53
# 77                           459                             302
# 78                           459                            1641
# 79                           459                            1641
# 80                           459                             375
# 81                           459                             294
# 82                           459                            1107
# ...                          ...                             ...
# 23662                       2018                            2015
# 23666                       1217                            1213
# 23686                        310                             311
# 23691                        580                             582
# 23722                       2227                            2228
# 23729                       1746                            1748
# 23730                       1746                            1748
# 23731                       1746                            1748
# 23736                        966                              90
# 23737                        966                              90
# 23814                       1376                            1370
# 23854                       1861                            1860
# 23863                       1478                             455
# 23864                       1570                            1577
# 23900                       2265                            2299
# 23927                       1840                            1844
# 23944                       2040                            1176
# 23960                       1212                            1213
# 23961                       1203                            1213
# 23972                        161                             160
# 24020                         12                              18
# 24023                       2329                            2330
# 24035                       1271                             434
# 24102                       1721                            1723
# 24132                       2151                            2174
# 24143                        162                             158
# 24152                       1653                            1663
# 24335                       1749                            1590
# 24339                        661                             673
# 24344                        702                             737
#
#                                Collapsing.Job.Title.pred  \
# 0                           technical operations manager
# 1                           technical operations manager
# 5                           technical operations analyst
# 6                                audio visual technician
# 7                                               producer
# 8                          manufacturer representative s
# 9                          manufacturer representative s
# 10                                       general manager
# 11                                               manager
# 12                                               manager
# 13                                               manager
# 14                                              designer
# 15                                              designer
# 16                                            accountant
# 17                                                intern
# 18                                                intern
# 19                                    operations manager
# 20                                     event coordinator
# 21                                              educator
# 22                                 laboratory technician
# 23                                     creative director
# 74                                    director education
# 75                                   coordinator service
# 76                         acquisition specialist talent
# 77                                                  chef
# 78                                        representative
# 79                                        representative
# 80                                 clinic manager office
# 81                                  certified nurse aide
# 82                                        loan assistant
# ...                                                  ...
# 23662                                 shipping associate
# 23666                            marketing event manager
# 23686  chief executive officer chief financial office...
# 23691                           design director interior
# 23722                             v business development
# 23729                    senior administrative assistant
# 23730                    senior administrative assistant
# 23731                    senior administrative assistant
# 23736                                              agent
# 23737                                              agent
# 23814                  personal administrative assistant
# 23854                                   senior paralegal
# 23863                        control document specialist
# 23864                                   r representative
# 23900                             vice president officer
# 23927                           senior manager marketing
# 23944                                    manager quality
# 23960                            marketing event manager
# 23961                            marketing event manager
# 23972                   assistant vice president manager
# 24020                                 account specialist
# 24023              vice president strategic partnerships
# 24035                computer network support technician
# 24102                                       sales trader
# 24132                        technician support engineer
# 24143                   assistant vice president analyst
# 24152                             retail sales associate
# 24335                        receptionist office manager
# 24339                         director digital marketing
# 24344                        director system engineering
#
#                                   Collapsing.Job.Title  match
# 0                         technical operations analyst      0
# 1                         technical operations analyst      0
# 5                         technical operations manager      0
# 6                                          coordinator      0
# 7                                          coordinator      0
# 8                                          coordinator      0
# 9                                          coordinator      0
# 10                                         coordinator      0
# 11                                         coordinator      0
# 12                                         coordinator      0
# 13                                         coordinator      0
# 14                                         coordinator      0
# 15                                         coordinator      0
# 16                                         coordinator      0
# 17                                         coordinator      0
# 18                                         coordinator      0
# 19                                         coordinator      0
# 20                                         coordinator      0
# 21                                         coordinator      0
# 22                                         coordinator      0
# 23                                         coordinator      0
# 74                                         coordinator      0
# 75                                         coordinator      0
# 76                                         coordinator      0
# 77                                         coordinator      0
# 78                                         coordinator      0
# 79                                         coordinator      0
# 80                                         coordinator      0
# 81                                         coordinator      0
# 82                                         coordinator      0
# ...                                                ...    ...
# 23662                                 shipping manager      0
# 23666                     marketing operations manager      0
# 23686  chief executive officer chief financial officer      0
# 23691                                 design assistant      0
# 23722                                                v      0
# 23729                     senior accounting specialist      0
# 23730                     senior accounting specialist      0
# 23731                     senior accounting specialist      0
# 23736                                import specialist      0
# 23737                                import specialist      0
# 23814                         pharmacist personnel die      0
# 23854                                   senior partner      0
# 23863                            production specialist      0
# 23864                             quantitative analyst      0
# 23900               vice president business operations      0
# 23927            senior manager advertising operations      0
# 23944                     software development manager      0
# 23960                      marketing event coordinator      0
# 23961                         marketing communications      0
# 23972      assistant vice president operations manager      0
# 24020                               account receivable      0
# 24023                vice president strategic accounts      0
# 24035                            network support musca      0
# 24102                            sales support manager      0
# 24132                        technical product manager      0
# 24143    assistant vice president relationship manager      0
# 24152                                   research sales      0
# 24335                             senior administrator      0
# 24339                     director corporate marketing      0
# 24344                     director process engineering      0
#
# [2597 rows x 5 columns]
