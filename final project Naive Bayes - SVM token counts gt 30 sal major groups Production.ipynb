# %%
# Start final project import modules
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
# %matplotlib inline
import sys
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder 
from sklearn import feature_extraction
from __future__ import print_function
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %%
# read in the datasets
 
#jd = pd.read_csv('job_data_dict_30_sample.csv')
#jd = pd.read_csv('job_data_dict_sal_weighted_30_sample.csv')
#jd = pd.read_csv('job_data_dict_all_sal_weighted.csv')
jd = pd.read_csv('job_data_dict_all_sal_weighted_major.csv')

# %%
#1. Explore the dataset: 
    # There is a mix of string and numeric data. There are some variables that can be converted to dummy or binary values.
    # While there are no NAs there are unknown values in some of the string data which may need to be treated as NAs.

#jd.describe(include='all')
jd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9716 entries, 0 to 9715
# Data columns (total 12 columns):
# Unnamed: 0          9716 non-null int64
# major_des           9716 non-null object
# jobs                9716 non-null object
# jobtitle            9716 non-null object
# onetcode            9716 non-null object
# major_code          9716 non-null int64
# dictionary          9716 non-null object
# p_an                9716 non-null float64
# p_an_normal         9716 non-null float64
# lowct               9716 non-null int64
# major_dictionary    9716 non-null object
# uid                 9716 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 986.8+ KB

# %%
jd.head()
# Out:
#    Unnamed: 0   major_des                                       jobs  \
# 0           2  Management  computer and information systems managers
# 1           6  Management    financial managers branch or department
# 2          16  Management                   human resources managers
# 3          28  Management                 treasurers and controllers
# 4          31  Management    financial managers branch or department
#
#                                          jobtitle    onetcode  major_code  \
# 0  director of it planning development deployment  11-3021.00          11
# 1                   accounting manager supervisor  11-3031.02          11
# 2                         human resources manager  11-3040.00          11
# 3                            corporate controller  11-3031.01          11
# 4                   accounting manager supervisor  11-3031.02          11
#
#                                           dictionary      p_an  p_an_normal  \
# 0  director planning development deployment direc...  110000.0     0.097679
# 1  accounting manager supervisor accounting manag...   45000.0     0.031779
# 2  human resources manager human resources manage...   91197.5     0.078616
# 3  corporate controller corporate controller year...  115000.0     0.102748
# 4  accounting manager supervisor accounting manag...   82500.0     0.069798
#
#    lowct                                   major_dictionary  uid
# 0      0  computer information systems managers computer...    1
# 1      0  financial managers branch department financial...    2
# 2      0  human resources managers human resources manag...    3
# 3      0  treasurers controllers treasurers controllers ...    4
# 4      0  financial managers branch department financial...    5

# %%
cat_columns = ['major_des', 'jobs','jobtitle','dictionary','major_dictionary', 'p_an_normal', 'lowct']
major_feat_col = ['major_dictionary', 'p_an_normal']   
feat_col = ['dictionary', 'p_an_normal']
string_variables = ['jobs']

jd_2 = jd[cat_columns]
jd_2.head()
# Out:
#     major_des                                       jobs  \
# 0  Management  computer and information systems managers
# 1  Management    financial managers branch or department
# 2  Management                   human resources managers
# 3  Management                 treasurers and controllers
# 4  Management    financial managers branch or department
#
#                                          jobtitle  \
# 0  director of it planning development deployment
# 1                   accounting manager supervisor
# 2                         human resources manager
# 3                            corporate controller
# 4                   accounting manager supervisor
#
#                                           dictionary  \
# 0  director planning development deployment direc...
# 1  accounting manager supervisor accounting manag...
# 2  human resources manager human resources manage...
# 3  corporate controller corporate controller year...
# 4  accounting manager supervisor accounting manag...
#
#                                     major_dictionary  p_an_normal  lowct
# 0  computer information systems managers computer...     0.097679      0
# 1  financial managers branch department financial...     0.031779      0
# 2  human resources managers human resources manag...     0.078616      0
# 3  treasurers controllers treasurers controllers ...     0.102748      0
# 4  financial managers branch department financial...     0.069798      0

# %%
# subset the data to the major groups
jd_3 = jd_2[jd_2.major_des=='Production']
jd_3 = jd_3[jd_3.lowct==0]

# %%
jd_3.jobs.value_counts().min()
# Out:
# 22

# %%
#df_numerical = jd_2.copy()
#encoder_dict = {}

#for col in string_variables:
#    le = preprocessing.LabelEncoder()
#    le.fit(jd_2[col])
#    encoder_dict[col] = le
#    df_numerical[col] = le.transform(jd_2[col])

#df_numerical.head()

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(jd_3[feat_col], jd_3['jobs'], random_state=1)

# %%
#feat = list(df_numerical.dictionary.values.flatten())
#type(feat)
#feat = unicode(feat, 'utf-8')

# %%
#df_numerical.dictionary[0]
#import sys  

#reload(sys)  
#sys.setdefaultencoding('utf8')
#y_test

# %%
X_test.shape
# Out:
# (101L, 2L)

# %%
X_train.shape
# Out:
# (303L, 2L)

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(decode_error = 'ignore')
#vect = CountVectorizer()
#vect.fit(X_train)
#vect.transform(X_train)

# %%
#vect.get_feature_names()
# learn vocabulary and create document-term matrix in a single step
train_dtm = vect.fit_transform(X_train[:,0])
train_dtm
# Out:
# <303x781 sparse matrix of type '<type 'numpy.int64'>'
# 	with 2745 stored elements in Compressed Sparse Row format>

# %%
# transform testing data into a document-term matrix
test_dtm = vect.transform(X_test[:,0])
type(test_dtm)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
train_features = vect.get_feature_names()
len(train_features)
# Out:
# 781

# %%
train_features = train_features + list('s')

# %%
len(train_features)
# Out:
# 782

# %%
train_sal = np.array(X_train[:,1])
train_sal = train_sal[...,None]
type(train_sal)
# Out:
# numpy.ndarray

# %%
test_sal = np.array(X_test[:,1])
test_sal = test_sal[...,None]
type(test_sal)
# Out:
# numpy.ndarray

# %%
train_dtm_2 = np.array(train_dtm.todense())
type(train_dtm_2)
# Out:
# numpy.ndarray

# %%
test_dtm_2 = np.array(test_dtm.todense())

# %%
test_dtm_2.shape
# Out:
# (101L, 781L)

# %%
train_dtm_2.shape
# Out:
# (303L, 781L)

# %%
train_dtm2 = np.append(train_dtm_2, train_sal,1)

# %%
type(train_dtm2)
train_dtm2.shape
# Out:
# (303L, 782L)

# %%
test_dtm2 = np.append(test_dtm_2, test_sal, 1)

# %%
# convert train_dtm to a regular array
#train_arr = train_dtm2.toarray()
#train_arr

# %%
# exercise: create a DataFrame of tokens with their counts.
train_token_counts = pd.DataFrame({'token':train_features, 'count':np.sum(train_dtm2, axis=0)})
train_token_counts.sort_index(by='count', ascending=False)
# Out:
#     count               token
# 544   363          production
# 33    151            assembly
# 566   125             quality
# 333   115           inspector
# 772   100              worker
# 691    96          supervisor
# 410    89       manufacturing
# 643    81               shift
# 403    77             manager
# 29     76           assembler
# 132    59             control
# 391    55           machinist
# 705    54          technician
# 110    49             company
# 273    42             general
# 228    37          experience
# 468    36            operator
# 39     36           associate
# 36     31           assistant
# 472    31         opportunity
# 517    30            position
# 701    29                team
# 425    27          mechanical
# 103    26                 cnc
# 633    26             seeking
# 774    23             workers
# 299    23              hiring
# 780    23               years
# 592    21        requirements
# 518    21           positions
# ..    ...                 ...
# 752     1               waste
# 184     1           documents
# 754     1                week
# 183     1          documented
# 756     1              welded
# 757     1             welders
# 182     1       documentation
# 759     1           weldments
# 181     1                docs
# 180     1  distributioncenter
# 178     1        distributing
# 177     1          disposable
# 764     1             winning
# 173     1               dirty
# 766     1               wires
# 172     1             directs
# 768     1            withgood
# 769     1            wondered
# 155     1       dependability
# 157     1           depending
# 5       1           accuforce
# 773     1    workeromnisource
# 165     1          developing
# 775     1          workersfor
# 162     1            detailed
# 2       1           accepting
# 778     1            worksite
# 160     1           desirable
# 1       1       acceptability
# 470     1        opportunites
#
# [782 rows x 2 columns]

# %%
# train a Naive Bayes model using train_dtm
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(train_dtm2, y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:427: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   self.feature_count_ += safe_sparse_dot(Y.T, X)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# make predictions on test data using test_dtm
preds = nb.predict(test_dtm2)
preds
# Out:
# array(['supervisors of production and operating staff', 'machinists',
#        'helpers production workers', 'production workers',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff',
#        'assemblers and fabricators', 'helpers production workers',
#        'machinists', 'production workers', 'assemblers and fabricators',
#        'helpers production workers', 'production workers',
#        'assemblers and fabricators', 'production workers',
#        'assemblers and fabricators', 'production workers',
#        'production workers', 'helpers production workers',
#        'assemblers and fabricators', 'production workers',
#        'supervisors of production and operating staff', 'team assemblers',
#        'helpers production workers', 'assemblers and fabricators',
#        'supervisors of production and operating staff',
#        'helpers production workers',
#        'supervisors of production and operating staff',
#        'production workers',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff', 'machinists',
#        'supervisors of production and operating staff',
#        'production workers', 'assemblers and fabricators',
#        'production workers',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff',
#        'helpers production workers',
#        'inspectors testers sorters samplers and weighers',
#        'production workers', 'helpers production workers',
#        'assemblers and fabricators',
#        'electrical and electronic equipment assemblers',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'production workers', 'production workers',
#        'inspectors testers sorters samplers and weighers',
#        'assemblers and fabricators',
#        'supervisors of production and operating staff',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff',
#        'helpers production workers',
#        'supervisors of production and operating staff',
#        'assemblers and fabricators',
#        'electrical and electronic equipment assemblers',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'assemblers and fabricators',
#        'inspectors testers sorters samplers and weighers',
#        'production workers',
#        'inspectors testers sorters samplers and weighers', 'machinists',
#        'assemblers and fabricators', 'assemblers and fabricators',
#        'helpers production workers', 'production workers',
#        'inspectors testers sorters samplers and weighers',
#        'production workers',
#        'supervisors of production and operating staff',
#        'inspectors testers sorters samplers and weighers',
#        'production workers',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'electrical and electronic equipment assemblers',
#        'production workers',
#        'supervisors of production and operating staff',
#        'helpers production workers', 'production workers',
#        'helpers production workers', 'team assemblers',
#        'inspectors testers sorters samplers and weighers', 'machinists',
#        'assemblers and fabricators',
#        'inspectors testers sorters samplers and weighers',
#        'supervisors of production and operating staff',
#        'helpers production workers', 'helpers production workers',
#        'production workers', 'helpers production workers',
#        'supervisors of production and operating staff',
#        'production workers',
#        'supervisors of production and operating staff',
#        'supervisors of production and operating staff',
#        'helpers production workers', 'team assemblers',
#        'supervisors of production and operating staff'],
#       dtype='|S48')

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, preds))
print(metrics.confusion_matrix(y_test, preds))
# Out:
# 0.683168316832
# [[ 9  1  0  2  0  2  0  0]
#  [ 2  2  1  0  0  0  0  1]
#  [ 0  0  8  0  0  5  0  0]
#  [ 1  0  2 10  0  0  0  0]
#  [ 0  0  0  0  5  0  0  0]
#  [ 0  0  5  0  0  8  0  0]
#  [ 1  0  0  1  0  3 25  0]
#  [ 1  0  0  0  0  3  1  2]]

# %%
# predict (poorly calibrated) probabilities and calculate AUC
#probs = nb.predict_proba(test_dtm2)[:, 1]
#probs
#print(metrics.roc_auc_score(y_test, probs))

# %%
# exercise: show the message text for the false positives
#X_test[y_test < preds]

# %%
# exercise: show the message text for the false negatives
#X_test[y_test > preds]

# %%
from sklearn.metrics import classification_report 

print(classification_report(y_test, preds) )
# Out:
#              precision    recall  f1-score   support
#
# assemblers and fabricators       0.64      0.64      0.64        14
# electrical and electronic equipment assemblers       0.67      0.33      0.44         6
# helpers production workers       0.50      0.62      0.55        13
# inspectors testers sorters samplers and weighers       0.77      0.77      0.77        13
#  machinists       1.00      1.00      1.00         5
# production workers       0.38      0.62      0.47        13
# supervisors of production and operating staff       0.96      0.83      0.89        30
# team assemblers       0.67      0.29      0.40         7
#
# avg / total       0.72      0.68      0.69       101

# %%
# use SVM
from sklearn import svm
from sklearn import metrics
svc = svm.SVC(kernel='linear', probability = True)

svc.fit(train_dtm2, y_train)
# make predictions on test data using test_dtm
preds = svc.predict(test_dtm2)

print(metrics.accuracy_score(y_test, preds))
# Out:
# 0.693069306931

# %%
#from sklearn.cross_validation import cross_val_score
#cross_val_score(nb, train_dtm, y_train, cv=5, scoring='accuracy').mean()

# %%
# try using all of the data

# %%
train_dtm = vect.fit_transform(jd_3['dictionary'])
train_dtm_2 = np.array(train_dtm.todense())
type(train_dtm_2)
# Out:
# numpy.ndarray

# %%
train_sal = np.array(jd_3['p_an_normal'])
train_sal = train_sal[...,None]
type(train_sal)
# Out:
# numpy.ndarray

# %%
train_dtm2 = np.append(train_dtm_2, train_sal,1)

# %%
# train a Naive Bayes model using train_dtm
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(train_dtm2, jd_3['jobs'])
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
preds = nb.predict(train_dtm2)
preds.shape
# Out:
# (404L,)

# %%
print(classification_report(jd_3['jobs'], preds) )
# Out:
#              precision    recall  f1-score   support
#
# assemblers and fabricators       0.75      0.91      0.83        47
# electrical and electronic equipment assemblers       0.95      0.91      0.93        22
# helpers production workers       0.88      0.93      0.90        54
# inspectors testers sorters samplers and weighers       0.95      0.93      0.94        59
#  machinists       1.00      1.00      1.00        29
# production workers       0.77      0.90      0.83        51
# supervisors of production and operating staff       1.00      0.91      0.95       115
# team assemblers       0.94      0.59      0.73        27
#
# avg / total       0.91      0.90      0.90       404

# %%
target_predicted = nb.predict(train_dtm2)
target_prob = nb.predict_proba(train_dtm2)

#print(target_test)
#print(target_predicted)
#print(target_prob.mean())

pd.crosstab(jd_3['jobs'], target_predicted, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted                                         assemblers and fabricators  \
# True
# assemblers and fabricators                                                43
# electrical and electronic equipment assemblers                             2
# helpers production workers                                                 2
# inspectors testers sorters samplers and weighers                           2
# machinists                                                                 0
# production workers                                                         1
# supervisors of production and operating staff                              3
# team assemblers                                                            4
# All                                                                       57
#
# Predicted                                         electrical and electronic equipment assemblers  \
# True
# assemblers and fabricators                                                                     0
# electrical and electronic equipment assemblers                                                20
# helpers production workers                                                                     0
# inspectors testers sorters samplers and weighers                                               0
# machinists                                                                                     0
# production workers                                                                             0
# supervisors of production and operating staff                                                  1
# team assemblers                                                                                0
# All                                                                                           21
#
# Predicted                                         helpers production workers  \
# True
# assemblers and fabricators                                                 0
# electrical and electronic equipment assemblers                             0
# helpers production workers                                                50
# inspectors testers sorters samplers and weighers                           2
# machinists                                                                 0
# production workers                                                         4
# supervisors of production and operating staff                              1
# team assemblers                                                            0
# All                                                                       57
#
# Predicted                                         inspectors testers sorters samplers and weighers  \
# True
# assemblers and fabricators                                                                       0
# electrical and electronic equipment assemblers                                                   0
# helpers production workers                                                                       0
# inspectors testers sorters samplers and weighers                                                55
# machinists                                                                                       0
# production workers                                                                               0
# supervisors of production and operating staff                                                    3
# team assemblers                                                                                  0
# All                                                                                             58
#
# Predicted                                         machinists  \
# True
# assemblers and fabricators                                 0
# electrical and electronic equipment assemblers             0
# helpers production workers                                 0
# inspectors testers sorters samplers and weighers           0
# machinists                                                29
# production workers                                         0
# supervisors of production and operating staff              0
# team assemblers                                            0
# All                                                       29
#
# Predicted                                         production workers  \
# True
# assemblers and fabricators                                         4
# electrical and electronic equipment assemblers                     0
# helpers production workers                                         2
# inspectors testers sorters samplers and weighers                   0
# machinists                                                         0
# production workers                                                46
# supervisors of production and operating staff                      1
# team assemblers                                                    7
# All                                                               60
#
# Predicted                                         supervisors of production and operating staff  \
# True
# assemblers and fabricators                                                                    0
# electrical and electronic equipment assemblers                                                0
# helpers production workers                                                                    0
# inspectors testers sorters samplers and weighers                                              0
# machinists                                                                                    0
# production workers                                                                            0
# supervisors of production and operating staff                                               105
# team assemblers                                                                               0
# All                                                                                         105
#
# Predicted                                         team assemblers  All
# True
# assemblers and fabricators                                      0   47
# electrical and electronic equipment assemblers                  0   22
# helpers production workers                                      0   54
# inspectors testers sorters samplers and weighers                0   59
# machinists                                                      0   29
# production workers                                              0   51
# supervisors of production and operating staff                   1  115
# team assemblers                                                16   27
# All                                                            17  404

# %%
from sklearn.cross_validation import cross_val_score
cross_val_score(nb, train_dtm, jd_3['jobs'], cv=5, scoring='accuracy').mean()
# Out:
# 0.72041594951233512
